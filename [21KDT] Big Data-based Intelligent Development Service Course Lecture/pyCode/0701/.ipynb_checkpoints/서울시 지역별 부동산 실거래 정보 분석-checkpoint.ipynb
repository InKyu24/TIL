# %% [markdown]
# ### 미션: 구별, 동단위 건물주 용별 평균 시세
# * 1. 구 단위 데이터 조회
#     * 구 이름 입력
#     * 파일에서 해당 구 이름을 기준으로 데이터 조회
#     * '자치구명', '법정동명', '건물주용도', '건축년도', '건물면적', '층정보', '물건금액', '건물명' 리스트 데이터 추가

# %%
# 사용자로부터 구명, 동명을 입력받아 조회
# 출력값 : '자치구명', '법정동명', '건물주용도', '건축년도', '건물면적', '층정보', '물건금액', '건물명'
#                3         5           15(-4)       17(-2)       11        13         16(-3)     18(-1)
import csv
import matplotlib.pyplot as plt

g_name = input('조회 구 이름 입력:')
#d_name = input('조회 동 이름 입력:')

f = open('./data/서울특별시_부동산_실거래가_정보_2020년.csv')
data = csv.reader(f)
header = next(data)

data_lst = []
for row in data:
    if g_name == row[3]:
        #d_name in row[5]:
        data_lst.append([row[3],row[5],row[-4],row[-2],row[11],row[13],row[-3],row[-1]])
        
f.close()
data_lst
# Out:
# 조회 구 이름 입력:성북구
# [['성북구', '장위동', '아파트', '0', '59.920000', '5', '749000000', '래미안 장위포레카운티'],
#  ['성북구', '길음동', '아파트', '0', '84.770000', '18', '1200000000', '롯데캐슬 클라시아 '],
#  ['성북구', '장위동', '아파트', '0', '116.910000', '2', '1270000000', '래미안장위퍼스트하이'],
#  ['성북구', '석관동', '아파트', '1998', '84.900000', '17', '647000000', '두산'],
#  ['성북구', '석관동', '단독주택', '1973', '59.970000', '', '270000000', ''],
#  ['성북구', '장위동', '아파트', '0', '59.990000', '17', '820000000', '래미안장위퍼스트하이'],
#  ['성북구', '성북동', '단독주택', '1980', '19.830000', '', '400000000', ''],
#  ['성북구', '돈암동', '아파트', '1994', '84.720000', '12', '494000000', '동소문현대'],
#  ['성북구', '정릉동', '단독주택', '1970', '61.350000', '', '295000000', ''],
#  ['성북구', '장위동', '단독주택', '1970', '62.550000', '', '714600000', ''],
#  ['성북구', '장위동', '아파트', '0', '84.480000', '12', '1150000000', '꿈의숲 아이파크'],
#  ['성북구', '길음동', '단독주택', '1994', '119.250000', '', '500000000', ''],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '22', '628000000', '동아에코빌'],
#  ['성북구', '길음동', '아파트', '0', '84.770000', '8', '1160000000', '롯데캐슬 클라시아 '],
#  ['성북구', '장위동', '아파트', '0', '84.480000', '18', '1300000000', '꿈의숲 아이파크'],
#  ['성북구', '동선동5가', '연립주택', '1993', '69.240000', '1', '254000000', '씨티빌라'],
#  ['성북구', '길음동', '아파트', '0', '59.970000', '10', '900000000', '래미안길음센터피스'],
#  ['성북구', '길음동', '아파트', '0', '59.780000', '7', '917000000', '롯데캐슬 클라시아 '],
#  ['성북구', '장위동', '아파트', '0', '76.150000', '25', '1015000000', '꿈의숲 아이파크'],
#  ['성북구', '동선동3가', '단독주택', '1992', '112.500000', '', '625000000', ''],
#  ['성북구', '길음동', '아파트', '0', '84.950000', '23', '1420000000', '래미안길음센터피스'],
#  ['성북구', '길음동', '아파트', '0', '59.970000', '6', '910000000', '래미안길음센터피스'],
#  ['성북구', '장위동', '단독주택', '1973', '189.000000', '', '700000000', ''],
#  ['성북구', '길음동', '아파트', '0', '84.980000', '29', '1437000000', '래미안길음센터피스'],
#  ['성북구', '장위동', '단독주택', '1991', '138.060000', '', '350000000', ''],
#  ['성북구', '석관동', '아파트', '1998', '54.550000', '5', '577000000', '두산'],
#  ['성북구', '정릉동', '단독주택', '1987', '106.770000', '', '800000000', ''],
#  ['성북구', '정릉동', '아파트', '2006', '59.770000', '2', '475000000', '정릉e-편한세상'],
#  ['성북구', '장위동', '아파트', '0', '84.480000', '14', '1083530000', '꿈의숲 아이파크'],
#  ['성북구', '종암동', '아파트', '1999', '59.860000', '27', '610000000', '종암에스케이'],
#  ['성북구', '정릉동', '아파트', '1999', '59.900000', '3', '380000000', '쌍용2'],
#  ['성북구', '길음동', '아파트', '0', '84.770000', '27', '1331000000', '롯데캐슬 클라시아 '],
#  ['성북구', '장위동', '아파트', '0', '59.100000', '11', '995000000', '꿈의숲 아이파크'],
#  ['성북구', '장위동', '아파트', '0', '59.920000', '9', '850000000', '래미안포레카운티'],
#  ['성북구', '길음동', '단독주택', '1955', '33.060000', '', '440000000', ''],
#  ['성북구', '삼선동1가', '단독주택', '1979', '144.160000', '', '740000000', ''],
#  ['성북구', '장위동', '아파트', '0', '59.100000', '25', '850000000', '꿈의숲 아이파크'],
#  ['성북구', '하월곡동', '단독주택', '1995', '108.500000', '', '362500000', ''],
#  ['성북구', '장위동', '연립주택', '2003', '55.580000', '2', '225000000', '(229-42)'],
#  ['성북구', '길음동', '아파트', '2005', '59.990000', '9', '600000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '돈암동', '아파트', '1998', '59.790000', '18', '575000000', '범양'],
#  ['성북구', '길음동', '아파트', '0', '84.770000', '18', '1350000000', '롯데캐슬 클라시아 '],
#  ['성북구', '하월곡동', '단독주택', '1971', '72.730000', '', '620000000', ''],
#  ['성북구', '장위동', '단독주택', '1971', '69.090000', '', '513000000', ''],
#  ['성북구', '장위동', '단독주택', '1971', '81.520000', '', '395000000', ''],
#  ['성북구', '장위동', '아파트', '0', '59.920000', '9', '850000000', '래미안포레카운티'],
#  ['성북구', '석관동', '연립주택', '2019', '42.870000', '3', '279000000', '토성하우스'],
#  ['성북구', '동소문동5가', '아파트', '2006', '84.960000', '6', '873000000', '돈암동일하이빌'],
#  ['성북구', '길음동', '아파트', '0', '59.970000', '18', '950000000', '래미안길음센터피스'],
#  ['성북구', '길음동', '아파트', '0', '59.970000', '8', '955000000', '래미안길음센터피스'],
#  ['성북구', '길음동', '아파트', '0', '84.990000', '8', '1300000000', '래미안길음센터피스'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '84.820000',
#   '12',
#   '755500000',
#   '길음뉴타운8단지(래미안)'],
#  ['성북구', '종암동', '단독주택', '1960', '42.100000', '', '507500000', ''],
#  ['성북구', '장위동', '단독주택', '1992', '397.760000', '', '1100000000', ''],
#  ['성북구', '보문동6가', '아파트', '1994', '84.900000', '2', '509000000', '아남'],
#  ['성북구', '길음동', '연립주택', '', '87.110000', '1', '100000000', '대원연립'],
#  ['성북구', '길음동', '연립주택', '', '99.080000', '1', '100000000', '대원연립'],
#  ['성북구', '길음동', '연립주택', '1991', '35.850000', '-1', '120000000', '(524-62)'],
#  ['성북구', '장위동', '연립주택', '1995', '31.910000', '4', '185000000', '제일빌라'],
#  ['성북구', '장위동', '연립주택', '1994', '40.750000', '2', '280000000', '창신빌라5차'],
#  ['성북구', '장위동', '연립주택', '2019', '27.540000', '2', '290000000', '베아트리스'],
#  ['성북구', '정릉동', '아파트', '2015', '84.560000', '8', '680000000', '정릉꿈에그린'],
#  ['성북구', '정릉동', '아파트', '2015', '84.560000', '11', '700000000', '정릉꿈에그린'],
#  ['성북구', '삼선동3가', '아파트', '2012', '59.960000', '14', '800000000', '삼선에스케이뷰'],
#  ['성북구', '정릉동', '아파트', '1977', '71.500000', '2', '322000000', '산장아파트 가동, 나동'],
#  ['성북구', '정릉동', '아파트', '1999', '55.460000', '18', '350000000', '태영'],
#  ['성북구', '종암동', '아파트', '2005', '59.680000', '17', '618000000', '아이파크종암동 2차'],
#  ['성북구', '정릉동', '아파트', '1999', '59.420000', '17', '360000000', '태영'],
#  ['성북구', '종암동', '아파트', '2005', '59.610000', '15', '617000000', '아이파크종암동 2차'],
#  ['성북구', '안암동3가', '아파트', '1971', '60.930000', '3', '170000000', '대광'],
#  ['성북구', '돈암동', '아파트', '2003', '80.540000', '2', '600000000', '동부센트레빌'],
#  ['성북구', '정릉동', '아파트', '1999', '59.420000', '3', '350000000', '태영'],
#  ['성북구', '정릉동', '아파트', '2005', '73.280000', '16', '500000000', '정릉하이츠빌2단지'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '19', '595000000', '한진(609-1)'],
#  ['성북구', '장위동', '연립주택', '1977', '43.830000', '1', '390000000', '동방연립'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '6', '425000000', '한진(609-1)'],
#  ['성북구', '정릉동', '연립주택', '2008', '62.700000', '2', '240000000', '단풍나무빌라2'],
#  ['성북구', '성북동', '연립주택', '1996', '51.750000', '2', '299900000', '(168-5)'],
#  ['성북구', '하월곡동', '아파트', '2011', '126.600000', '31', '850000000', '동일하이빌뉴시티'],
#  ['성북구', '종암동', '아파트', '2008', '84.520000', '23', '640000000', '우림카이저팰리스'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '84.640000',
#   '17',
#   '790000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '하월곡동', '아파트', '2007', '59.980000', '19', '620000000', '월곡래미안루나밸리'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '59.980000',
#   '2',
#   '700000000',
#   '길음뉴타운7단지(두산위브)'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '15', '420000000', '한진(609-1)'],
#  ['성북구', '성북동', '연립주택', '1993', '45.090000', '-1', '230000000', '팔복빌라'],
#  ['성북구', '장위동', '연립주택', '1993', '35.650000', '3', '372000000', '청산빌라'],
#  ['성북구', '정릉동', '연립주택', '1983', '147.420000', '3', '320000000', '삼익빌라'],
#  ['성북구', '장위동', '연립주택', '2003', '51.720000', '3', '280000000', '진한그랑빌B동'],
#  ['성북구', '정릉동', '아파트', '2005', '84.950000', '3', '500000000', '정릉하이츠빌2단지'],
#  ['성북구', '종암동', '아파트', '2004', '59.990000', '1', '540000000', '삼성래미안'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '60.000000',
#   '15',
#   '614000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '장위동', '연립주택', '1995', '54.120000', '2', '255000000', '제일빌라'],
#  ['성북구', '장위동', '연립주택', '1998', '53.670000', '4', '180000000', '은하빌라'],
#  ['성북구', '장위동', '아파트', '0', '84.970000', '21', '1000000000', '래미안포레카운티'],
#  ['성북구', '돈암동', '연립주택', '2014', '41.070000', '5', '232000000', '돈암반석빌'],
#  ['성북구', '종암동', '아파트', '2004', '59.990000', '12', '646000000', '삼성래미안'],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '5', '567000000', '삼선푸르지오'],
#  ['성북구', '성북동', '아파트', '2002', '113.540000', '5', '695000000', '성북좋은'],
#  ['성북구', '돈암동', '연립주택', '1994', '67.230000', '3', '240000000', '(74-261)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '84.990000',
#   '9',
#   '898000000',
#   '길음뉴타운7단지(두산위브)'],
#  ['성북구', '돈암동', '아파트', '1991', '41.580000', '11', '362000000', '돈암현대아파트'],
#  ['성북구', '정릉동', '아파트', '2004', '84.980000', '15', '580000000', '정릉하이츠빌1단지'],
#  ['성북구', '돈암동', '아파트', '1998', '113.670000', '9', '720000000', '한진(609-1)'],
#  ['성북구', '정릉동', '연립주택', '2014', '51.310000', '4', '290000000', '에이스빌'],
#  ['성북구', '정릉동', '단독주택', '1985', '436.040000', '', '1500000000', ''],
#  ['성북구', '길음동', '아파트', '2005', '59.990000', '11', '527000000', '길음뉴타운3단지푸르지오'],
#  ['성북구', '정릉동', '단독주택', '1992', '126.960000', '', '305000000', ''],
#  ['성북구', '정릉동', '아파트', '2009', '59.900000', '11', '427500000', '우정에쉐르'],
#  ['성북구', '돈암동', '아파트', '1991', '56.700000', '9', '445000000', '돈암현대아파트'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '5', '350000000', '정릉풍림아이원'],
#  ['성북구', '정릉동', '아파트', '1999', '84.920000', '6', '380000000', '우방'],
#  ['성북구', '돈암동', '아파트', '1991', '84.390000', '13', '568000000', '돈암현대아파트'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '14', '720000000', '래미안월곡'],
#  ['성북구',
#   '돈암동',
#   '아파트',
#   '1999',
#   '114.410000',
#   '8',
#   '560000000',
#   '돈암동 풍림아파트 101~105동'],
#  ['성북구', '돈암동', '아파트', '1991', '41.580000', '5', '353000000', '돈암현대아파트'],
#  ['성북구', '길음동', '아파트', '2006', '59.750000', '6', '690000000', '길음뉴타운5단지(래미안)'],
#  ['성북구', '돈암동', '연립주택', '2009', '71.930000', '3', '283000000', '돈암골드뷰'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '59.970000',
#   '15',
#   '640000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '길음동', '아파트', '0', '84.980000', '26', '1126150000', '롯데캐슬 클라시아 '],
#  ['성북구', '석관동', '단독주택', '1972', '72.630000', '', '335000000', ''],
#  ['성북구', '정릉동', '연립주택', '1988', '35.400000', '-1', '80000000', '(266-568)'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '14', '727000000', '래미안월곡'],
#  ['성북구', '장위동', '연립주택', '2003', '36.390000', '4', '145000000', '(238-183)'],
#  ['성북구', '장위동', '연립주택', '1996', '59.350000', '2', '231000000', '도원맨션(나)동'],
#  ['성북구', '장위동', '연립주택', '2002', '50.980000', '3', '205000000', '상민아트빌 101동'],
#  ['성북구', '하월곡동', '아파트', '2006', '59.750000', '19', '625000000', '래미안월곡'],
#  ['성북구', '장위동', '연립주택', '1997', '46.810000', '4', '173000000', '신궁전맨션 5차'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '7', '410000000', '한진(609-1)'],
#  ['성북구', '석관동', '연립주택', '2013', '41.790000', '3', '230000000', '(334-44)'],
#  ['성북구', '정릉동', '아파트', '2009', '59.370000', '1', '530000000', '정릉2차e-편한세상'],
#  ['성북구', '동선동1가', '오피스텔', '2010', '49.070000', '3', '309000000', '코아루센타시아'],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '4', '580000000', '꿈의숲푸르지오'],
#  ['성북구', '길음동', '연립주택', '1998', '43.110000', '1', '100000000', '초원빌라A,B동'],
#  ['성북구', '삼선동4가', '연립주택', '2019', '25.040000', '6', '220000000', '에버그린'],
#  ['성북구', '삼선동4가', '연립주택', '2019', '24.900000', '5', '240000000', '에버그린'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '9', '630000000', '보문파크뷰자이'],
#  ['성북구', '보문동6가', '아파트', '2017', '84.990000', '10', '947000000', '보문파크뷰자이'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '2', '498000000', '한신'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.810000', '12', '800000000', '보문파크뷰자이'],
#  ['성북구', '장위동', '연립주택', '2016', '50.750000', '6', '340000000', '동방라온가(A,B동)'],
#  ['성북구', '석관동', '아파트', '1994', '59.790000', '5', '380000000', '중앙하이츠'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '4', '720000000', '래미안월곡'],
#  ['성북구', '길음동', '아파트', '1998', '111.710000', '10', '685000000', '돈암2-1삼부'],
#  ['성북구', '하월곡동', '아파트', '2007', '59.980000', '9', '620000000', '월곡래미안루나밸리'],
#  ['성북구', '장위동', '아파트', '0', '59.920000', '5', '749000000', '래미안 장위포레카운티'],
#  ['성북구', '안암동1가', '아파트', '2005', '114.930000', '2', '785000000', '안암동삼성래미안'],
#  ['성북구', '장위동', '아파트', '2002', '84.690000', '6', '380000000', '그린빌아파트'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '7', '569000000', '한진(609-1)'],
#  ['성북구', '장위동', '연립주택', '1995', '63.910000', '4', '290000000', '대창아트빌라'],
#  ['성북구', '장위동', '연립주택', '1982', '82.110000', '3', '323000000', '진한타운'],
#  ['성북구', '장위동', '연립주택', '2003', '57.120000', '4', '243000000', '동방로드빌'],
#  ['성북구', '성북동', '연립주택', '1993', '50.890000', '2', '296000000', '삼원렉스빌(B)'],
#  ['성북구', '장위동', '연립주택', '1995', '49.350000', '3', '178000000', '유성빌라'],
#  ['성북구', '돈암동', '아파트', '2016', '84.870000', '12', '900000000', '돈암코오롱하늘채'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '60.000000',
#   '7',
#   '600000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '장위동', '연립주택', '1992', '40.170000', '-1', '205000000', '성원빌라'],
#  ['성북구', '보문동6가', '아파트', '2017', '84.990000', '13', '940000000', '보문파크뷰자이'],
#  ['성북구', '길음동', '아파트', '2005', '59.990000', '3', '530000000', '길음뉴타운2단지푸르지오'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '59.990000',
#   '3',
#   '695000000',
#   '길음뉴타운7단지(두산위브)'],
#  ['성북구', '장위동', '연립주택', '2006', '45.360000', '5', '153000000', '토암트윈스빌(A동)'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '10', '364000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '2004', '59.990000', '19', '553000000', '이수브라운스톤돈암'],
#  ['성북구', '정릉동', '아파트', '2009', '114.960000', '8', '785000000', '정릉2차e-편한세상'],
#  ['성북구', '정릉동', '아파트', '1999', '84.490000', '17', '515000000', '쌍용2'],
#  ['성북구', '정릉동', '아파트', '2005', '84.090000', '4', '455000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '2', '450000000', '한신'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '4', '530000000', '한신'],
#  ['성북구', '성북동', '연립주택', '1987', '41.580000', '2', '210000000', '동구주택'],
#  ['성북구', '성북동', '연립주택', '1971', '22.350000', '2', '235000000', '(179-127)'],
#  ['성북구', '돈암동', '아파트', '2005', '117.160000', '2', '630000000', '일신건영휴먼빌아파트'],
#  ['성북구', '정릉동', '아파트', '1999', '84.920000', '15', '398000000', '우방'],
#  ['성북구', '장위동', '연립주택', '2002', '58.100000', '3', '233000000', '동방래미안'],
#  ['성북구', '정릉동', '아파트', '1999', '59.940000', '7', '320000000', '우방'],
#  ['성북구', '장위동', '연립주택', '1997', '51.660000', '4', '195000000', '동해빌라트 B동'],
#  ['성북구', '정릉동', '아파트', '2008', '84.650000', '5', '597500000', '라온유'],
#  ['성북구', '종암동', '아파트', '2011', '114.980000', '12', '1042000000', '래미안라센트'],
#  ['성북구', '정릉동', '아파트', '1999', '59.900000', '10', '420000000', '정릉스카이 쌍용 아파트'],
#  ['성북구', '정릉동', '아파트', '2007', '84.850000', '5', '590000000', '정릉힐스테이트1차'],
#  ['성북구', '돈암동', '아파트', '2005', '84.980000', '2', '603000000', '일신건영휴먼빌아파트'],
#  ['성북구', '정릉동', '아파트', '2008', '84.650000', '10', '599000000', '라온유'],
#  ['성북구', '정릉동', '아파트', '1977', '52.890000', '10', '242000000', '산장아파트 가동, 나동'],
#  ['성북구', '성북동', '연립주택', '1996', '59.560000', '4', '360000000', '스위스빌라'],
#  ['성북구', '정릉동', '아파트', '1977', '71.500000', '8', '300000000', '산장아파트 가동, 나동'],
#  ['성북구', '정릉동', '아파트', '1977', '52.890000', '2', '250000000', '산장아파트 가동, 나동'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.810000', '14', '780000000', '보문파크뷰자이'],
#  ['성북구', '정릉동', '아파트', '1977', '71.500000', '2', '328000000', '산장아파트 가동, 나동'],
#  ['성북구', '정릉동', '아파트', '2004', '94.590000', '15', '495000000', '정릉대주파크빌'],
#  ['성북구', '삼선동4가', '아파트', '1999', '59.940000', '12', '530000000', '코오롱'],
#  ['성북구', '정릉동', '단독주택', '1980', '94.080000', '', '1538000000', ''],
#  ['성북구', '정릉동', '아파트', '1999', '114.760000', '11', '530000000', '태영'],
#  ['성북구', '보문동6가', '아파트', '2017', '72.970000', '14', '920000000', '보문파크뷰자이'],
#  ['성북구', '돈암동', '아파트', '2016', '84.870000', '15', '885000000', '돈암코오롱하늘채'],
#  ['성북구',
#   '돈암동',
#   '아파트',
#   '1999',
#   '114.410000',
#   '9',
#   '570000000',
#   '돈암동 풍림아파트 101~105동'],
#  ['성북구', '돈암동', '아파트', '2016', '59.930000', '16', '740000000', '돈암코오롱하늘채'],
#  ['성북구', '성북동', '연립주택', '1995', '37.200000', '-1', '210000000', '그린빌라'],
#  ['성북구', '장위동', '아파트', '2003', '50.950000', '1', '330000000', '세영아파트'],
#  ['성북구', '성북동', '연립주택', '1995', '37.710000', '1', '250000000', '신성주택'],
#  ['성북구', '종암동', '아파트', '2005', '59.680000', '8', '618000000', '아이파크종암동 2차'],
#  ['성북구', '하월곡동', '단독주택', '1965', '47.610000', '', '320000000', ''],
#  ['성북구',
#   '돈암동',
#   '아파트',
#   '1999',
#   '84.680000',
#   '12',
#   '499000000',
#   '돈암동 풍림아파트 101~105동'],
#  ['성북구', '석관동', '아파트', '1999', '112.230000', '14', '630000000', '코오롱'],
#  ['성북구', '하월곡동', '아파트', '2007', '84.880000', '5', '750000000', '월곡래미안루나밸리'],
#  ['성북구', '장위동', '단독주택', '1988', '132.360000', '', '490000000', ''],
#  ['성북구', '장위동', '아파트', '2008', '84.840000', '12', '735000000', '꿈의숲대명루첸아파트'],
#  ['성북구', '석관동', '단독주택', '1992', '224.400000', '', '847000000', ''],
#  ['성북구', '종암동', '아파트', '2005', '59.680000', '10', '600000000', '아이파크종암동 2차'],
#  ['성북구', '종암동', '연립주택', '2011', '47.090000', '4', '193000000', '평화'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '15', '728000000', '래미안월곡'],
#  ['성북구', '보문동3가', '아파트', '2013', '84.900000', '11', '785000000', '이편한세상 보문'],
#  ['성북구', '돈암동', '아파트', '1999', '84.590000', '15', '614000000', '돈암동삼성'],
#  ['성북구', '정릉동', '아파트', '2003', '84.960000', '8', '497000000', '정릉푸른마을동아'],
#  ['성북구', '삼선동2가', '아파트', '2009', '56.830000', '8', '600000000', '삼선현대힐스테이트'],
#  ['성북구', '삼선동4가', '연립주택', '2019', '25.740000', '3', '335000000', '에버그린'],
#  ['성북구', '삼선동3가', '아파트', '2012', '122.440000', '8', '1150000000', '삼선에스케이뷰'],
#  ['성북구', '성북동', '연립주택', '2016', '56.480000', '2', '380000000', '리안캐슬(178-67)'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '10', '420000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '1999', '84.590000', '23', '590000000', '돈암동삼성'],
#  ['성북구', '돈암동', '아파트', '1998', '113.670000', '15', '666000000', '한신'],
#  ['성북구', '삼선동4가', '연립주택', '1986', '35.400000', '2', '150000000', '(14-0)'],
#  ['성북구',
#   '돈암동',
#   '아파트',
#   '1999',
#   '84.680000',
#   '15',
#   '520000000',
#   '돈암동 풍림아파트 101~105동'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '8', '613000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '2014', '84.880000', '8', '840000000', '길음역금호어울림센터힐'],
#  ['성북구', '정릉동', '아파트', '2006', '114.560000', '10', '600000000', '정릉e-편한세상'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.810000', '8', '817000000', '보문파크뷰자이'],
#  ['성북구', '하월곡동', '연립주택', '2019', '29.760000', '9', '261000000', '명남더블레스'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '19', '410000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '2014', '59.840000', '17', '700000000', '길음역금호어울림센터힐'],
#  ['성북구', '삼선동5가', '연립주택', '2002', '77.220000', '2', '345000000', '동원빌라트'],
#  ['성북구', '동선동4가', '연립주택', '1991', '55.080000', '4', '377000000', '우정빌라(가)'],
#  ['성북구', '하월곡동', '아파트', '2007', '84.880000', '8', '750000000', '월곡래미안루나밸리'],
#  ['성북구', '석관동', '아파트', '1998', '84.900000', '18', '630000000', '두산'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '15', '417000000', '한진(609-1)'],
#  ['성북구', '하월곡동', '아파트', '2007', '59.980000', '6', '660000000', '월곡래미안루나밸리'],
#  ['성북구', '정릉동', '아파트', '1999', '59.900000', '1', '350000000', '쌍용2'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '19', '530000000', '두산'],
#  ['성북구', '하월곡동', '아파트', '2004', '79.980000', '3', '530000000', '샹그레빌'],
#  ['성북구', '장위동', '연립주택', '1992', '39.870000', '3', '185000000', '성원빌라'],
#  ['성북구', '동선동4가', '연립주택', '2003', '64.190000', '-1', '480000000', '현대파크빌'],
#  ['성북구', '정릉동', '아파트', '1999', '59.590000', '1', '410000000', '경남'],
#  ['성북구', '종암동', '아파트', '2004', '59.730000', '17', '625000000', '아이파크종암동 1차'],
#  ['성북구', '정릉동', '아파트', '1999', '59.590000', '4', '430000000', '경남'],
#  ['성북구', '종암동', '아파트', '2004', '59.990000', '13', '590000000', '삼성래미안'],
#  ['성북구', '종암동', '아파트', '2005', '59.680000', '3', '595000000', '아이파크종암동 2차'],
#  ['성북구', '종암동', '아파트', '2004', '114.980000', '2', '730000000', '삼성래미안'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '18', '530000000', '한신'],
#  ['성북구', '석관동', '아파트', '1998', '134.970000', '16', '740000000', '두산'],
#  ['성북구', '돈암동', '아파트', '2014', '59.500000', '6', '688000000', '길음역금호어울림센터힐'],
#  ['성북구', '돈암동', '아파트', '1998', '132.960000', '9', '725000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '1999', '59.400000', '11', '462000000', '돈암동삼성'],
#  ['성북구', '정릉동', '아파트', '2005', '84.680000', '19', '590000000', '정릉하이츠빌2단지'],
#  ['성북구', '장위동', '단독주택', '1994', '84.160000', '', '360000000', ''],
#  ['성북구', '장위동', '연립주택', '2002', '82.670000', '3', '420000000', '푸른산빌라'],
#  ['성북구', '돈암동', '아파트', '2003', '80.540000', '6', '690000000', '동부센트레빌'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '18', '425000000', '한진(609-1)'],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '7', '600000000', '삼선푸르지오'],
#  ['성북구', '안암동1가', '아파트', '2005', '114.930000', '6', '780000000', '안암동삼성래미안'],
#  ['성북구', '돈암동', '아파트', '2003', '80.540000', '4', '680000000', '동부센트레빌'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '15', '750000000', '래미안월곡'],
#  ['성북구', '돈암동', '아파트', '2014', '119.560000', '6', '925000000', '길음역금호어울림센터힐'],
#  ['성북구', '성북동', '연립주택', '1998', '50.270000', '-1', '280000000', '반석빌라'],
#  ['성북구', '장위동', '아파트', '2002', '84.690000', '4', '360000000', '그린빌아파트'],
#  ['성북구',
#   '장위동',
#   '연립주택',
#   '2004',
#   '59.940000',
#   '2',
#   '215000000',
#   '명신아트빌(229-32)'],
#  ['성북구', '종암동', '아파트', '2009', '59.920000', '12', '670000000', '래미안세레니티'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '84.640000',
#   '3',
#   '690000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '59.990000',
#   '12',
#   '830000000',
#   '길음뉴타운8단지(래미안)'],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '1999',
#   '109.270000',
#   '19',
#   '598000000',
#   '정릉스카이 쌍용 아파트'],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '2000',
#   '84.990000',
#   '4',
#   '500000000',
#   '정릉우성아파트 101~105동'],
#  ['성북구', '종암동', '아파트', '2009', '84.990000', '6', '820000000', '래미안세레니티'],
#  ['성북구', '정릉동', '아파트', '1999', '84.490000', '18', '510000000', '쌍용2'],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '8', '550000000', '동아에코빌'],
#  ['성북구', '정릉동', '아파트', '2009', '84.400000', '10', '685000000', '정릉2차e-편한세상'],
#  ['성북구', '길음동', '아파트', '0', '59.990000', '15', '1000000000', '래미안 길음 센터피스 '],
#  ['성북구', '정릉동', '연립주택', '1993', '89.830000', '1', '155000000', '스카이힐스'],
#  ['성북구', '정릉동', '아파트', '2004', '84.980000', '3', '535000000', '정릉하이츠빌1단지'],
#  ['성북구', '성북동', '연립주택', '1996', '57.050000', '4', '293000000', '스위스빌라'],
#  ['성북구', '길음동', '아파트', '2010', '59.990000', '6', '768000000', '길음뉴타운8단지(래미안)'],
#  ['성북구', '석관동', '단독주택', '1970', '70.750000', '', '365000000', ''],
#  ['성북구', '종암동', '아파트', '2000', '84.960000', '2', '475000000', '극동'],
#  ['성북구', '정릉동', '연립주택', '2002', '53.700000', '1', '160000000', '굿모닝빌'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '59.970000',
#   '12',
#   '589000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '84.640000',
#   '5',
#   '820000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '정릉동', '아파트', '2015', '84.560000', '12', '670000000', '정릉꿈에그린'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '12', '354000000', '정릉풍림아이원'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.840000',
#   '20',
#   '668500000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '상월곡동', '아파트', '1994', '84.510000', '10', '452000000', '우남푸르미아'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.960000',
#   '8',
#   '870000000',
#   '길음뉴타운1단지(래미안길음1차)'],
#  ['성북구', '길음동', '아파트', '2005', '59.770000', '13', '509000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '0', '59.780000', '20', '927790000', '롯데캐슬 클라시아 '],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '84.640000',
#   '8',
#   '805000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '장위동', '아파트', '2020', '59.990000', '19', '865000000', '래미안장위퍼스트하이'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '6', '670000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '돈암동', '아파트', '1998', '152.250000', '17', '790000000', '한진(609-1)'],
#  ['성북구', '정릉동', '아파트', '2008', '84.650000', '7', '620000000', '라온유'],
#  ['성북구', '돈암동', '아파트', '1999', '114.660000', '5', '615000000', '돈암동삼성'],
#  ['성북구', '삼선동1가', '단독주택', '1961', '45.520000', '', '302000000', ''],
#  ['성북구', '성북동', '단독주택', '1965', '48.300000', '', '550000000', ''],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '7', '548000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '3', '500000000', '동아에코빌'],
#  ['성북구', '정릉동', '아파트', '2004', '84.920000', '19', '600000000', '정릉힐스테이트'],
#  ['성북구', '성북동', '단독주택', '1964', '146.140000', '', '1200000000', ''],
#  ['성북구', '정릉동', '아파트', '1999', '59.260000', '11', '308000000', '정릉중앙하이츠아파트'],
#  ['성북구', '상월곡동', '연립주택', '2019', '45.070000', '5', '370000000', '토티하우스'],
#  ['성북구', '석관동', '단독주택', '1978', '224.290000', '', '954000000', ''],
#  ['성북구', '정릉동', '아파트', '1977', '71.500000', '1', '305000000', '산장아파트 가동, 나동'],
#  ['성북구', '종암동', '아파트', '2004', '114.980000', '4', '665000000', '삼성래미안'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '14', '450000000', '동아에코빌'],
#  ['성북구', '성북동', '아파트', '2002', '92.570000', '4', '610000000', '성북좋은'],
#  ['성북구', '석관동', '단독주택', '1992', '198.900000', '', '682500000', ''],
#  ['성북구', '상월곡동', '아파트', '2003', '114.660000', '4', '600000000', '동아에코빌'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2007',
#   '59.370000',
#   '15',
#   '820000000',
#   '길음뉴타운6단지(래미안)'],
#  ['성북구', '정릉동', '연립주택', '1994', '62.080000', '1', '185000000', '경원그린빌라'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '20', '589000000', '한진(609-1)'],
#  ['성북구', '정릉동', '연립주택', '1992', '40.920000', '1', '105000000', '금정빌라'],
#  ['성북구', '정릉동', '연립주택', '2015', '26.450000', '3', '145000000', '삼성센스빌'],
#  ['성북구', '장위동', '연립주택', '1997', '41.890000', '1', '170000000', '동해빌라트 B동'],
#  ['성북구', '정릉동', '아파트', '2001', '59.980000', '14', '380000000', '대우'],
#  ['성북구', '길음동', '아파트', '2005', '114.730000', '8', '819000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '장위동', '연립주택', '2004', '55.640000', '2', '350000000', '대성아트빌'],
#  ['성북구', '석관동', '아파트', '2011', '84.920000', '12', '673000000', '신동아파밀리에'],
#  ['성북구', '종암동', '아파트', '2011', '84.990000', '19', '840000000', '래미안라센트'],
#  ['성북구', '하월곡동', '아파트', '2003', '114.750000', '15', '680000000', '월곡두산위브'],
#  ['성북구', '정릉동', '단독주택', '1980', '45.160000', '', '343000000', ''],
#  ['성북구', '석관동', '아파트', '2011', '115.580000', '6', '738000000', '신동아파밀리에'],
#  ['성북구', '정릉동', '연립주택', '1984', '93.150000', '3', '490000000', '대광빌라'],
#  ['성북구', '석관동', '아파트', '2009', '59.900000', '3', '590000000', '석관래미안'],
#  ['성북구', '길음동', '아파트', '0', '59.970000', '10', '947000000', '래미안 길음 센터피스 '],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '2000',
#   '59.970000',
#   '6',
#   '410000000',
#   '정릉우성아파트 101~105동'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '19', '465000000', '동아에코빌'],
#  ['성북구', '돈암동', '아파트', '2016', '84.960000', '9', '895000000', '돈암코오롱하늘채'],
#  ['성북구', '석관동', '단독주택', '1996', '117.710000', '', '409500000', ''],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '17', '670000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '종암동', '아파트', '2004', '84.950000', '4', '705000000', '삼성래미안'],
#  ['성북구', '길음동', '아파트', '2005', '59.990000', '10', '560000000', '길음뉴타운2단지푸르지오'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '114.730000',
#   '11',
#   '760000000',
#   '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '2', '690000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '돈암동', '아파트', '2004', '114.890000', '3', '900000000', '이수브라운스톤돈암'],
#  ['성북구', '길음동', '아파트', '2005', '59.770000', '16', '540000000', '길음뉴타운3단지푸르지오'],
#  ['성북구', '장위동', '연립주택', '2003', '61.730000', '4', '245000000', '수인쉐르빌 B동'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.840000', '11', '620000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.840000', '17', '645000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2003', '59.860000', '3', '530000000', '월곡두산위브'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '10', '623000000', '한진(609-1)'],
#  ['성북구', '하월곡동', '아파트', '2003', '114.750000', '1', '650000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.840000', '15', '640000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2003', '59.860000', '12', '556000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2010', '84.730000', '7', '648000000', '꿈의숲푸르지오'],
#  ['성북구', '하월곡동', '아파트', '2003', '59.860000', '2', '545000000', '월곡두산위브'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.990000', '9', '600000000', '월곡두산위브'],
#  ['성북구', '정릉동', '연립주택', '2002', '56.760000', '2', '215000000', '금강메트로빌'],
#  ['성북구', '장위동', '아파트', '0', '84.970000', '21', '1000000000', '래미안포레카운티'],
#  ['성북구', '하월곡동', '아파트', '2003', '59.860000', '2', '525000000', '월곡두산위브'],
#  ['성북구', '삼선동2가', '아파트', '2008', '84.840000', '10', '704000000', '삼선푸르지오'],
#  ['성북구', '장위동', '연립주택', '2003', '84.830000', '3', '450000000', '인성하이츠빌'],
#  ['성북구', '보문동6가', '연립주택', '2015', '36.880000', '4', '280000000', '웰하우스'],
#  ['성북구', '정릉동', '아파트', '2008', '84.970000', '6', '600000000', '정릉힐스테이트3차'],
#  ['성북구', '삼선동3가', '아파트', '2012', '84.950000', '13', '1047000000', '삼선에스케이뷰'],
#  ['성북구', '장위동', '아파트', '0', '59.100000', '24', '400000000', '꿈의숲 아이파크'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '7', '605000000', '한진(609-1)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2006',
#   '59.750000',
#   '10',
#   '693000000',
#   '길음뉴타운5단지(래미안)'],
#  ['성북구', '정릉동', '단독주택', '1993', '149.330000', '', '435600000', ''],
#  ['성북구', '길음동', '아파트', '2019', '84.930000', '20', '770000000', '롯데캐슬골든힐스'],
#  ['성북구', '정릉동', '단독주택', '1971', '69.780000', '', '427370000', ''],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2006',
#   '114.930000',
#   '3',
#   '920000000',
#   '길음뉴타운5단지(래미안)'],
#  ['성북구', '정릉동', '연립주택', '1987', '49.920000', '1', '150000000', '영빈파크빌라'],
#  ['성북구', '장위동', '단독주택', '1975', '83.520000', '', '550000000', ''],
#  ['성북구',
#   '장위동',
#   '연립주택',
#   '2004',
#   '59.940000',
#   '5',
#   '200000000',
#   '명신아트빌(229-32)'],
#  ['성북구', '정릉동', '단독주택', '1980', '65.130000', '', '330000000', ''],
#  ['성북구', '장위동', '연립주택', '2003', '40.370000', '2', '130000000', '(238-194)'],
#  ['성북구', '정릉동', '연립주택', '2010', '60.040000', '2', '200000000', '효성아트빌(2차)'],
#  ['성북구', '돈암동', '아파트', '2004', '59.990000', '14', '615000000', '이수브라운스톤돈암'],
#  ['성북구', '돈암동', '아파트', '2004', '59.990000', '10', '600000000', '이수브라운스톤돈암'],
#  ['성북구', '장위동', '연립주택', '2007', '82.320000', '4', '350000000', '현대베스트빌A동'],
#  ['성북구', '삼선동4가', '아파트', '1999', '59.940000', '17', '560000000', '코오롱'],
#  ['성북구', '장위동', '연립주택', '1997', '33.400000', '4', '240000000', '우성빌라'],
#  ['성북구', '종암동', '아파트', '1999', '59.860000', '14', '460000000', '종암에스케이'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '59.990000',
#   '18',
#   '648000000',
#   '길음뉴타운1단지(래미안길음1차)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '59.860000',
#   '9',
#   '600000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '보문동3가', '아파트', '2013', '84.900000', '15', '785000000', '이편한세상 보문'],
#  ['성북구', '종암동', '아파트', '2005', '59.680000', '5', '590000000', '아이파크종암동 2차'],
#  ['성북구', '보문동3가', '아파트', '2003', '59.490000', '2', '594000000', '현대I-PARK'],
#  ['성북구', '장위동', '연립주택', '1992', '46.430000', '1', '173000000', '길복빌라'],
#  ['성북구', '장위동', '연립주택', '2016', '43.450000', '5', '250000000', '세영 그린빌'],
#  ['성북구', '길음동', '아파트', '0', '59.870000', '13', '897000000', '롯데캐슬 클라시아 '],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '6', '560000000', '꿈의숲푸르지오'],
#  ['성북구', '상월곡동', '연립주택', '2019', '28.600000', '2', '220000000', '토티하우스'],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '10', '558000000', '꿈의숲푸르지오'],
#  ['성북구', '종암동', '단독주택', '1971', '28.760000', '', '240000000', ''],
#  ['성북구', '석관동', '아파트', '1998', '84.900000', '2', '635000000', '두산'],
#  ['성북구', '장위동', '단독주택', '1993', '149.880000', '', '475000000', ''],
#  ['성북구', '동선동5가', '단독주택', '1992', '162.090000', '', '730000000', ''],
#  ['성북구', '정릉동', '연립주택', '2017', '52.820000', '4', '275000000', '(376-6)'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.190000', '16', '810000000', '보문파크뷰자이'],
#  ['성북구', '길음동', '아파트', '2010', '84.960000', '1', '840000000', '길음뉴타운9단지(래미안)'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '7', '640000000', '보문파크뷰자이'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.810000', '10', '800000000', '보문파크뷰자이'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '7', '400000000', '정릉풍림아이원'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '2', '650000000', '보문파크뷰자이'],
#  ['성북구', '보문동6가', '아파트', '2017', '72.900000', '1', '840000000', '보문파크뷰자이'],
#  ['성북구', '정릉동', '아파트', '2004', '84.980000', '16', '547000000', '정릉하이츠빌1단지'],
#  ['성북구', '장위동', '단독주택', '1974', '116.690000', '', '1063000000', ''],
#  ['성북구', '길음동', '연립주택', '2012', '59.520000', '3', '248000000', '휴먼타운'],
#  ['성북구', '동소문동7가', '아파트', '2004', '59.910000', '5', '588000000', '한신플러스C'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '3', '652000000', '보문파크뷰자이'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '13', '730000000', '래미안월곡'],
#  ['성북구', '돈암동', '아파트', '2016', '59.930000', '6', '760000000', '돈암코오롱하늘채'],
#  ['성북구', '정릉동', '연립주택', '2008', '59.850000', '2', '220000000', '삼성그린빌라'],
#  ['성북구', '장위동', '연립주택', '1994', '58.560000', '-1', '168000000', '엘림빌라'],
#  ['성북구', '돈암동', '아파트', '1998', '132.960000', '15', '670000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '8', '430000000', '한진(609-1)'],
#  ['성북구', '장위동', '아파트', '2008', '59.990000', '4', '600000000', '꿈의숲대명루첸아파트'],
#  ['성북구', '장위동', '아파트', '2008', '103.530000', '7', '800000000', '꿈의숲대명루첸아파트'],
#  ['성북구', '동소문동7가', '아파트', '2004', '84.950000', '3', '675000000', '한신플러스C'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '3', '640000000', '보문파크뷰자이'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '5', '432000000', '동아에코빌'],
#  ['성북구', '정릉동', '아파트', '2001', '84.830000', '11', '438000000', '대우'],
#  ['성북구', '돈암동', '아파트', '2004', '114.890000', '2', '810000000', '이수브라운스톤돈암'],
#  ['성북구', '돈암동', '아파트', '1999', '84.590000', '21', '580000000', '돈암동삼성'],
#  ['성북구', '정릉동', '아파트', '2005', '59.980000', '6', '530000000', '정릉푸르지오'],
#  ['성북구', '정릉동', '아파트', '2005', '59.980000', '11', '530000000', '정릉푸르지오'],
#  ['성북구', '종암동', '아파트', '2004', '59.990000', '1', '550000000', '삼성래미안'],
#  ['성북구', '상월곡동', '아파트', '2003', '114.660000', '7', '647000000', '동아에코빌'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '11', '748000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '11', '650000000', '길음뉴타운3단지푸르지오'],
#  ['성북구', '하월곡동', '단독주택', '1983', '256.140000', '', '1320000000', ''],
#  ['성북구', '종암동', '아파트', '2004', '114.980000', '14', '840000000', '삼성래미안'],
#  ['성북구', '종암동', '아파트', '2004', '84.950000', '14', '749000000', '삼성래미안'],
#  ['성북구', '삼선동4가', '단독주택', '1996', '299.640000', '', '1250000000', ''],
#  ['성북구', '장위동', '연립주택', '1996', '57.170000', '4', '325000000', '초림아트빌라'],
#  ['성북구', '장위동', '연립주택', '1996', '58.520000', '1', '180000000', '승한빌라'],
#  ['성북구', '석관동', '아파트', '2009', '114.970000', '20', '795000000', '석관래미안'],
#  ['성북구', '석관동', '연립주택', '2013', '37.010000', '5', '130000000', '충효하우스'],
#  ['성북구', '장위동', '오피스텔', '2019', '18.030000', '3', '110000000', '석계역 한일노벨리아시티'],
#  ['성북구', '정릉동', '연립주택', '2001', '58.860000', '1', '200000000', '금강아트빌'],
#  ['성북구', '성북동', '연립주택', '2002', '57.720000', '-1', '150000000', '효송빌라'],
#  ['성북구', '장위동', '오피스텔', '2019', '18.030000', '3', '117000000', '석계역 한일노벨리아시티'],
#  ['성북구', '정릉동', '아파트', '2009', '59.370000', '5', '555000000', '정릉2차e-편한세상'],
#  ['성북구', '장위동', '연립주택', '1989', '41.100000', '1', '120000000', '(68-833)'],
#  ['성북구', '정릉동', '아파트', '1999', '59.900000', '16', '421000000', '쌍용2'],
#  ['성북구', '보문동3가', '아파트', '2013', '84.900000', '9', '785000000', '이편한세상 보문'],
#  ['성북구', '정릉동', '아파트', '2015', '59.630000', '15', '623000000', '정릉꿈에그린'],
#  ['성북구', '정릉동', '아파트', '2005', '84.890000', '12', '599000000', '정릉푸르지오'],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '9', '608000000', '삼선푸르지오'],
#  ['성북구', '동소문동7가', '아파트', '2004', '59.910000', '1', '535000000', '한신플러스C'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.870000', '6', '800000000', '보문파크뷰자이'],
#  ['성북구', '하월곡동', '단독주택', '1968', '65.130000', '', '330000000', ''],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '1', '580000000', '삼선푸르지오'],
#  ['성북구', '삼선동2가', '아파트', '2008', '114.650000', '3', '815000000', '삼선푸르지오'],
#  ['성북구', '정릉동', '연립주택', '1984', '88.380000', '1', '440000000', '대광빌라'],
#  ['성북구', '석관동', '아파트', '1994', '84.850000', '5', '420000000', '중앙하이츠'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '11', '650000000', '보문파크뷰자이'],
#  ['성북구', '돈암동', '아파트', '1999', '84.590000', '20', '579000000', '돈암동삼성'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '10', '510000000', '한신'],
#  ['성북구', '정릉동', '아파트', '2003', '81.090000', '8', '410000000', '대동황토방'],
#  ['성북구', '정릉동', '아파트', '2005', '84.090000', '14', '450000000', '정릉풍림아이원'],
#  ['성북구', '정릉동', '아파트', '2005', '114.750000', '6', '540000000', '정릉풍림아이원'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.840000', '3', '620000000', '월곡두산위브'],
#  ['성북구', '돈암동', '아파트', '2014', '59.500000', '19', '700000000', '길음역금호어울림센터힐'],
#  ['성북구', '동선동5가', '연립주택', '2009', '71.050000', '3', '335000000', '대도아트빌'],
#  ['성북구',
#   '하월곡동',
#   '아파트',
#   '2007',
#   '84.140000',
#   '9',
#   '682000000',
#   '성북힐스테이트(101동)'],
#  ['성북구', '길음동', '아파트', '2010', '59.990000', '7', '810000000', '길음뉴타운8단지(래미안)'],
#  ['성북구',
#   '하월곡동',
#   '아파트',
#   '2007',
#   '84.690000',
#   '7',
#   '630000000',
#   '성북힐스테이트(101동)'],
#  ['성북구', '종암동', '아파트', '2005', '84.730000', '1', '675000000', '아이파크종암동 2차'],
#  ['성북구', '삼선동1가', '연립주택', '1988', '40.500000', '2', '210000000', '미산빌라 A동'],
#  ['성북구', '정릉동', '아파트', '2007', '84.920000', '2', '550000000', '정릉힐스테이트1차'],
#  ['성북구', '하월곡동', '아파트', '2011', '126.600000', '34', '900000000', '동일하이빌뉴시티'],
#  ['성북구', '삼선동1가', '연립주택', '1988', '40.500000', '2', '190000000', '미산빌라 A동'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '9', '545000000', '두산'],
#  ['성북구', '동소문동7가', '아파트', '2004', '59.910000', '5', '588000000', '한신플러스C'],
#  ['성북구', '종암동', '아파트', '2000', '59.670000', '11', '470000000', '극동'],
#  ['성북구', '동선동5가', '연립주택', '2009', '64.740000', '2', '270000000', '대도아트빌'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '20', '450000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '2006', '84.820000', '9', '570000000', '돈암동더샵아파트'],
#  ['성북구', '하월곡동', '아파트', '2007', '84.880000', '4', '745000000', '월곡래미안루나밸리'],
#  ['성북구', '장위동', '연립주택', '1978', '50.020000', '2', '125000000', '(219-90)'],
#  ['성북구', '종암동', '아파트', '2000', '114.750000', '12', '690000000', '극동'],
#  ['성북구', '정릉동', '아파트', '2005', '84.680000', '21', '617000000', '정릉하이츠빌2단지'],
#  ['성북구', '삼선동2가', '아파트', '2008', '114.650000', '3', '717000000', '삼선푸르지오'],
#  ['성북구', '장위동', '연립주택', '2016', '58.440000', '4', '273000000', '경복하이빌A동'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '114.730000',
#   '12',
#   '798000000',
#   '길음뉴타운2단지푸르지오'],
#  ['성북구', '장위동', '단독주택', '1993', '78.670000', '', '300000000', ''],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '8', '600000000', '삼선푸르지오'],
#  ['성북구', '동소문동7가', '아파트', '2004', '84.950000', '2', '630000000', '한신플러스C'],
#  ['성북구', '길음동', '아파트', '2005', '114.730000', '5', '810000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '안암동3가', '아파트', '1971', '45.920000', '2', '170000000', '대광'],
#  ['성북구', '장위동', '아파트', '0', '59.990000', '11', '830000000', '래미안장위퍼스트하이'],
#  ['성북구', '길음동', '아파트', '0', '59.900000', '31', '947000000', '래미안길음센터피스'],
#  ['성북구', '종암동', '아파트', '1999', '114.750000', '22', '700000000', '종암에스케이'],
#  ['성북구', '종암동', '아파트', '1999', '59.860000', '14', '498000000', '종암에스케이'],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '12', '558000000', '꿈의숲푸르지오'],
#  ['성북구', '상월곡동', '단독주택', '1970', '56.860000', '', '405000000', ''],
#  ['성북구', '돈암동', '아파트', '2004', '84.970000', '3', '720000000', '이수브라운스톤돈암'],
#  ['성북구', '하월곡동', '아파트', '2010', '84.730000', '6', '650000000', '꿈의숲푸르지오'],
#  ['성북구', '삼선동4가', '아파트', '1999', '84.870000', '4', '695000000', '코오롱'],
#  ['성북구', '장위동', '연립주택', '1996', '53.200000', '1', '175000000', '도원맨션(가)동'],
#  ['성북구', '하월곡동', '아파트', '2010', '114.610000', '7', '765000000', '꿈의숲푸르지오'],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '7', '694000000', '보문파크뷰자이'],
#  ['성북구', '정릉동', '아파트', '1999', '59.900000', '17', '400000000', '쌍용2'],
#  ['성북구', '삼선동4가', '아파트', '1999', '59.940000', '8', '549000000', '코오롱'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '10', '649000000', '한신'],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '1', '552500000', '꿈의숲푸르지오'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '12', '657000000', '한신'],
#  ['성북구', '하월곡동', '아파트', '2010', '84.730000', '1', '600000000', '꿈의숲푸르지오'],
#  ['성북구', '종암동', '아파트', '2010', '84.970000', '10', '785000000', '종암2차SKVIEW'],
#  ['성북구', '돈암동', '아파트', '2003', '115.510000', '14', '840000000', '동부센트레빌'],
#  ['성북구', '하월곡동', '아파트', '2010', '59.650000', '2', '570000000', '꿈의숲푸르지오'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '12', '500000000', '한신'],
#  ['성북구', '보문동1가', '아파트', '0', '59.790000', '12', '719620000', '보문 리슈빌 하우트 '],
#  ['성북구',
#   '성북동',
#   '연립주택',
#   '2002',
#   '74.590000',
#   '4',
#   '440000000',
#   '삼보월드빌(나)(178-28)'],
#  ['성북구', '성북동', '연립주택', '1997', '43.950000', '1', '317000000', '아남하이츠(나)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '114.730000',
#   '13',
#   '801000000',
#   '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '9', '690000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '장위동', '아파트', '2008', '59.990000', '17', '630000000', '꿈의숲대명루첸아파트'],
#  ['성북구', '길음동', '아파트', '0', '84.980000', '14', '1148400000', '롯데캐슬 클라시아 '],
#  ['성북구', '삼선동4가', '연립주택', '2019', '23.610000', '6', '325000000', '에버그린'],
#  ['성북구', '석관동', '아파트', '1999', '59.940000', '14', '421000000', '코오롱'],
#  ['성북구', '길음동', '아파트', '0', '84.980000', '18', '1105400000', '롯데캐슬 클라시아 '],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '6', '540000000', '두산'],
#  ['성북구', '동소문동7가', '아파트', '2004', '59.910000', '18', '620000000', '한신플러스C'],
#  ['성북구', '보문동3가', '아파트', '2003', '84.570000', '6', '765000000', '현대I-PARK'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '9', '605000000', '한진(609-1)'],
#  ['성북구', '보문동3가', '아파트', '2003', '84.570000', '14', '787000000', '현대I-PARK'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '12', '420000000', '한진(609-1)'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '2', '570000000', '한진(609-1)'],
#  ['성북구', '장위동', '연립주택', '1995', '39.840000', '2', '190000000', '미라보빌라'],
#  ['성북구', '동선동4가', '연립주택', '2003', '69.840000', '-1', '475000000', '현대파크빌'],
#  ['성북구', '장위동', '연립주택', '2002', '55.000000', '4', '163000000', '반석그린빌'],
#  ['성북구', '종암동', '아파트', '2009', '59.970000', '22', '700000000', '래미안세레니티'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '84.960000',
#   '23',
#   '900000000',
#   '길음뉴타운9단지(래미안)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.960000',
#   '14',
#   '880000000',
#   '길음뉴타운1단지(래미안길음1차)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '59.980000',
#   '27',
#   '790000000',
#   '길음뉴타운9단지(래미안)'],
#  ['성북구', '석관동', '연립주택', '2019', '33.000000', '5', '343000000', '포레스트빌'],
#  ['성북구',
#   '정릉동',
#   '연립주택',
#   '2019',
#   '29.410000',
#   '2',
#   '198000000',
#   '천우네오젠(206-60)'],
#  ['성북구', '동선동5가', '연립주택', '2003', '70.970000', '3', '265000000', '두원빌라씨네마'],
#  ['성북구', '돈암동', '아파트', '1999', '114.660000', '8', '630000000', '돈암동삼성'],
#  ['성북구', '삼선동5가', '단독주택', '1996', '119.960000', '', '500000000', ''],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '114.730000',
#   '17',
#   '850000000',
#   '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '1988', '79.870000', '6', '380000000', '신안파크'],
#  ['성북구', '길음동', '아파트', '2005', '84.970000', '7', '688000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '길음동', '아파트', '2005', '59.990000', '13', '595000000', '길음뉴타운2단지푸르지오'],
#  ['성북구', '종암동', '아파트', '2004', '84.980000', '18', '783000000', '아이파크종암동 1차'],
#  ['성북구', '보문동6가', '아파트', '2017', '72.900000', '16', '897000000', '보문파크뷰자이'],
#  ['성북구', '종암동', '아파트', '2009', '84.990000', '18', '830000000', '래미안세레니티'],
#  ['성북구', '장위동', '연립주택', '2019', '29.960000', '5', '252000000', '성준팰리스(장위초A동)'],
#  ['성북구', '종암동', '아파트', '2005', '84.730000', '13', '720000000', '아이파크종암동 2차'],
#  ['성북구', '동소문동4가', '아파트', '1998', '84.870000', '14', '627000000', '송산아파트'],
#  ['성북구', '정릉동', '연립주택', '2018', '46.920000', '1', '285000000', '대성아트빌 153'],
#  ['성북구', '종암동', '아파트', '2004', '59.990000', '1', '570000000', '삼성래미안'],
#  ['성북구', '보문동3가', '아파트', '2013', '84.770000', '10', '757000000', '이편한세상 보문'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '59.990000',
#   '22',
#   '737000000',
#   '길음뉴타운8단지(래미안)'],
#  ['성북구', '하월곡동', '아파트', '1998', '84.780000', '19', '605000000', '동신'],
#  ['성북구', '보문동6가', '아파트', '2017', '72.970000', '13', '930000000', '보문파크뷰자이'],
#  ['성북구', '돈암동', '아파트', '2016', '59.860000', '14', '720000000', '돈암코오롱하늘채'],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '10', '547000000', '동아에코빌'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '114.990000',
#   '11',
#   '1190000000',
#   '길음뉴타운8단지(래미안)'],
#  ['성북구', '하월곡동', '아파트', '2011', '84.910000', '9', '625000000', '길음 서희스타힐스'],
#  ['성북구', '안암동3가', '아파트', '1971', '56.960000', '6', '230000000', '대광'],
#  ['성북구', '정릉동', '단독주택', '1982', '201.660000', '', '718000000', ''],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '19', '554000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '16', '457000000', '동아에코빌'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '114.980000',
#   '20',
#   '1200000000',
#   '길음뉴타운8단지(래미안)'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '13', '740000000', '래미안월곡'],
#  ['성북구', '상월곡동', '아파트', '2003', '114.660000', '8', '610000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '12', '457000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '1', '489500000', '동아에코빌'],
#  ['성북구', '정릉동', '연립주택', '2013', '34.600000', '4', '185000000', '372-25'],
#  ['성북구', '동소문동7가', '아파트', '2004', '59.910000', '16', '600000000', '한신플러스C'],
#  ['성북구', '상월곡동', '아파트', '1994', '59.640000', '2', '340000000', '우남푸르미아'],
#  ['성북구', '장위동', '연립주택', '2019', '57.330000', '2', '388000000', '성준팰리스(장위초A동)'],
#  ['성북구', '장위동', '연립주택', '2019', '54.570000', '5', '388000000', '성준팰리스(장위초B동)'],
#  ['성북구', '장위동', '연립주택', '2019', '29.970000', '3', '245000000', '(68-957)'],
#  ['성북구', '장위동', '연립주택', '2019', '29.910000', '5', '245000000', '(68-957)'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '59.860000',
#   '4',
#   '600000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '3', '556000000', '한진(609-1)'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '3', '723000000', '래미안월곡'],
#  ['성북구', '종암동', '단독주택', '1975', '172.070000', '', '1732500000', ''],
#  ['성북구', '성북동', '연립주택', '1997', '67.160000', '1', '335000000', '서흥빌라'],
#  ['성북구', '삼선동4가', '단독주택', '1994', '241.500000', '', '870000000', ''],
#  ['성북구', '삼선동2가', '아파트', '2008', '84.830000', '3', '680000000', '삼선푸르지오'],
#  ['성북구', '종암동', '아파트', '2000', '59.670000', '1', '440000000', '극동'],
#  ['성북구', '장위동', '단독주택', '1973', '126.750000', '', '625000000', ''],
#  ['성북구', '성북동', '연립주택', '1997', '83.680000', '1', '530000000', '금강주택'],
#  ['성북구', '장위동', '연립주택', '1997', '38.500000', '-1', '288000000', '진성맨션'],
#  ['성북구', '정릉동', '연립주택', '1987', '25.650000', '-1', '85000000', '영흥주택(640-66)'],
#  ['성북구', '장위동', '단독주택', '1989', '265.960000', '', '860000000', ''],
#  ['성북구', '하월곡동', '아파트', '1998', '59.880000', '2', '410000000', '동신'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '1', '560000000', '한진(609-1)'],
#  ['성북구', '장위동', '단독주택', '1987', '191.020000', '', '572000000', ''],
#  ['성북구', '하월곡동', '아파트', '2003', '84.840000', '18', '670000000', '월곡두산위브'],
#  ['성북구', '장위동', '연립주택', '2002', '46.720000', '5', '150000000', '투원베스트빌'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '13', '595000000', '한진(609-1)'],
#  ['성북구', '장위동', '연립주택', '2002', '44.040000', '1', '125000000', '명신아트빌(227-4)'],
#  ['성북구', '동소문동4가', '아파트', '2004', '114.970000', '6', '770000000', '한신플러스A'],
#  ['성북구', '장위동', '연립주택', '1992', '29.380000', '3', '195000000', '태영주택'],
#  ['성북구', '상월곡동', '아파트', '2003', '114.660000', '19', '600000000', '동아에코빌'],
#  ['성북구', '장위동', '연립주택', '2004', '44.640000', '4', '420000000', '하나주택2동'],
#  ['성북구', '성북동', '연립주택', '2019', '17.390000', '4', '160000000', '청호제'],
#  ['성북구', '석관동', '아파트', '1998', '164.920000', '16', '785000000', '두산'],
#  ['성북구', '석관동', '연립주택', '2019', '29.020000', '5', '247000000', '반아크하임'],
#  ['성북구', '장위동', '연립주택', '2019', '28.840000', '2', '234000000', '장위 아띠끄빌'],
#  ['성북구', '돈암동', '연립주택', '2002', '36.600000', '1', '110000000', '(74-298)'],
#  ['성북구', '하월곡동', '아파트', '2007', '84.880000', '16', '745000000', '월곡래미안루나밸리'],
#  ['성북구', '장위동', '단독주택', '1969', '67.770000', '', '400000000', ''],
#  ['성북구', '장위동', '단독주택', '1994', '118.020000', '', '464000000', ''],
#  ['성북구', '하월곡동', '아파트', '2007', '59.980000', '13', '650000000', '월곡래미안루나밸리'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.960000',
#   '11',
#   '840000000',
#   '길음뉴타운1단지(래미안길음1차)'],
#  ['성북구', '돈암동', '아파트', '1998', '132.960000', '12', '780000000', '한신'],
#  ['성북구', '석관동', '단독주택', '1971', '57.750000', '', '270000000', ''],
#  ['성북구', '삼선동2가', '아파트', '2008', '114.650000', '12', '760000000', '삼선푸르지오'],
#  ['성북구', '삼선동2가', '아파트', '2008', '59.950000', '2', '575000000', '삼선푸르지오'],
#  ['성북구', '삼선동5가', '연립주택', '2016', '40.170000', '5', '300000000', '드림캐슬'],
#  ['성북구', '장위동', '단독주택', '1993', '177.850000', '', '680000000', ''],
#  ['성북구', '보문동6가', '아파트', '2003', '73.280000', '5', '345000000', '동문골드빌B동'],
#  ['성북구', '정릉동', '연립주택', '2013', '37.860000', '5', '206000000', '중앙하이즈'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '2', '400000000', '한진(609-1)'],
#  ['성북구', '장위동', '단독주택', '1992', '205.860000', '', '600000000', ''],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '2000',
#   '84.960000',
#   '15',
#   '475000000',
#   '정릉우성아파트 101~105동'],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '2000',
#   '84.910000',
#   '8',
#   '450000000',
#   '정릉성원아파트 101동, 102동'],
#  ['성북구',
#   '정릉동',
#   '아파트',
#   '2000',
#   '84.990000',
#   '10',
#   '500000000',
#   '정릉우성아파트 101~105동'],
#  ['성북구', '정릉동', '연립주택', '1988', '36.900000', '-1', '75000000', '로얄빌라B'],
#  ['성북구', '길음동', '아파트', '2019', '59.930000', '6', '710000000', '롯데캐슬골든힐스'],
#  ['성북구', '하월곡동', '아파트', '2004', '79.980000', '9', '502000000', '샹그레빌'],
#  ['성북구', '보문동1가', '단독주택', '1999', '26.450000', '', '430000000', ''],
#  ['성북구', '정릉동', '단독주택', '1985', '68.690000', '', '363000000', ''],
#  ['성북구', '동소문동7가', '아파트', '2004', '114.970000', '12', '800000000', '한신플러스C'],
#  ['성북구', '석관동', '단독주택', '1996', '119.110000', '', '412000000', ''],
#  ['성북구', '장위동', '연립주택', '2019', '29.750000', '2', '280000000', '라인빌8차'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '18', '644000000', '한진(609-1)'],
#  ['성북구', '정릉동', '연립주택', '1990', '51.210000', '1', '180000000', '로얄주택나동'],
#  ['성북구', '장위동', '연립주택', '2017', '34.130000', '4', '120000000', '223-40'],
#  ['성북구', '하월곡동', '아파트', '2011', '66.610000', '8', '512000000', '길음 서희스타힐스'],
#  ['성북구', '장위동', '연립주택', '1986', '42.510000', '2', '395000000', '(233-338)'],
#  ['성북구', '정릉동', '연립주택', '2019', '57.340000', '5', '410000000', '파인캐슬'],
# ...
#  ['성북구', '정릉동', '단독주택', '1985', '63.630000', '', '475000000', ''],
#  ['성북구', '장위동', '단독주택', '1969', '171.340000', '', '650000000', ''],
#  ['성북구', '하월곡동', '아파트', '2003', '59.860000', '7', '555000000', '월곡두산위브'],
#  ['성북구', '돈암동', '아파트', '2013', '84.980000', '2', '650000000', '돈암동 해피트리'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '4', '460000000', '한신'],
#  ['성북구', '상월곡동', '아파트', '2003', '114.660000', '20', '613000000', '동아에코빌'],
#  ['성북구', '석관동', '연립주택', '2017', '29.930000', '5', '217000000', '초원빌리지'],
#  ['성북구', '석관동', '연립주택', '1993', '39.870000', '-1', '69000000', '단독형(261-252)'],
#  ['성북구', '정릉동', '아파트', '2005', '114.750000', '9', '557000000', '정릉풍림아이원'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '3', '420000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '6', '442000000', '동아에코빌'],
#  ['성북구', '정릉동', '아파트', '2005', '84.090000', '6', '458000000', '정릉풍림아이원'],
#  ['성북구', '석관동', '연립주택', '2019', '29.830000', '4', '230000000', '루체빌'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '7', '516000000', '두산'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2010',
#   '114.860000',
#   '1',
#   '1000000000',
#   '길음뉴타운9단지(래미안)'],
#  ['성북구', '종암동', '연립주택', '2015', '33.940000', '2', '230000000', '웰하우스'],
#  ['성북구', '정릉동', '아파트', '2004', '84.980000', '11', '548000000', '정릉하이츠빌1단지'],
#  ['성북구', '장위동', '연립주택', '1995', '43.510000', '1', '200000000', '영일아트빌라'],
#  ['성북구', '정릉동', '아파트', '2003', '59.400000', '3', '415000000', '정릉푸른마을동아'],
#  ['성북구', '정릉동', '아파트', '2003', '59.400000', '8', '405000000', '정릉푸른마을동아'],
#  ['성북구', '정릉동', '아파트', '2003', '84.960000', '6', '460000000', '정릉푸른마을동아'],
#  ['성북구', '삼선동3가', '연립주택', '1986', '70.560000', '1', '250000000', '경동빌라'],
#  ['성북구', '석관동', '아파트', '1998', '84.900000', '8', '650000000', '두산'],
#  ['성북구', '돈암동', '아파트', '2005', '84.980000', '8', '635000000', '일신건영휴먼빌아파트'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '84.640000',
#   '5',
#   '801000000',
#   '길음뉴타운4단지(e편한세상)'],
#  ['성북구', '장위동', '연립주택', '2019', '57.860000', '5', '370000000', '성준팰리스(장위초2)A'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '5', '385000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '2003', '80.540000', '5', '695000000', '동부센트레빌'],
#  ['성북구', '성북동', '단독주택', '1958', '43.800000', '', '340000000', ''],
#  ['성북구', '장위동', '연립주택', '1977', '43.830000', '1', '360000000', '동방연립'],
#  ['성북구', '상월곡동', '아파트', '1994', '59.640000', '12', '382000000', '우남푸르미아'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.840000',
#   '11',
#   '727000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '동소문동4가', '단독주택', '1990', '291.600000', '', '1150000000', ''],
#  ['성북구', '정릉동', '아파트', '2005', '84.090000', '12', '487000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '2006', '84.720000', '7', '600000000', '돈암동더샵아파트'],
#  ['성북구', '정릉동', '아파트', '1999', '84.920000', '11', '420000000', '우방'],
#  ['성북구', '장위동', '연립주택', '1995', '51.640000', '4', '450000000', '전주빌라8차'],
#  ['성북구', '성북동', '단독주택', '1967', '64.270000', '', '200000000', ''],
#  ['성북구', '삼선동5가', '연립주택', '2003', '50.910000', '2', '265000000', '벧엘하이츠'],
#  ['성북구', '장위동', '단독주택', '1987', '245.000000', '', '930000000', ''],
#  ['성북구', '종암동', '아파트', '1996', '75.500000', '17', '580000000', '종암선경'],
#  ['성북구', '정릉동', '아파트', '2006', '114.560000', '6', '660000000', '정릉e-편한세상'],
#  ['성북구', '정릉동', '아파트', '2006', '85.000000', '7', '525000000', '정릉e-편한세상'],
#  ['성북구', '정릉동', '아파트', '2008', '84.970000', '5', '600000000', '정릉힐스테이트3차'],
#  ['성북구', '성북동', '연립주택', '1992', '101.520000', '-1', '410000000', '청기와빌리지'],
#  ['성북구', '성북동', '단독주택', '1966', '30.810000', '', '220000000', ''],
#  ['성북구', '성북동', '연립주택', '2003', '67.140000', '2', '355000000', '대명아트빌'],
#  ['성북구', '장위동', '연립주택', '2002', '41.930000', '2', '150000000', '드림빌'],
#  ['성북구', '정릉동', '단독주택', '2003', '50.880000', '', '375000000', ''],
#  ['성북구', '하월곡동', '아파트', '1998', '84.780000', '7', '530000000', '동신'],
#  ['성북구', '정릉동', '연립주택', '2004', '54.300000', '3', '146000000', '썬하이츠빌'],
#  ['성북구', '종암동', '연립주택', '1999', '64.510000', '2', '240000000', '우성하우스빌'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '2', '520000000', '한신'],
#  ['성북구', '정릉동', '단독주택', '1985', '41.610000', '', '260000000', ''],
#  ['성북구', '장위동', '연립주택', '2016', '41.200000', '2', '258000000', '동방라온가(C,D동)'],
#  ['성북구', '장위동', '연립주택', '2019', '57.310000', '3', '350000000', '라인빌8차'],
#  ['성북구', '하월곡동', '아파트', '2003', '63.880000', '10', '390000000', '수산동양빌'],
#  ['성북구', '하월곡동', '아파트', '2003', '114.750000', '2', '650000000', '월곡두산위브'],
#  ['성북구', '종암동', '아파트', '2011', '84.990000', '17', '910000000', '래미안라센트'],
#  ['성북구', '정릉동', '아파트', '2005', '84.090000', '12', '449000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '2004', '59.990000', '4', '610000000', '이수브라운스톤돈암'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '16', '375000000', '정릉풍림아이원'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '5', '510000000', '한신'],
#  ['성북구', '보문동6가', '아파트', '2017', '59.810000', '7', '850000000', '보문파크뷰자이'],
#  ['성북구', '석관동', '아파트', '2009', '114.970000', '15', '800000000', '석관래미안'],
#  ['성북구', '석관동', '단독주택', '1990', '135.450000', '', '420000000', ''],
#  ['성북구', '정릉동', '아파트', '2004', '84.920000', '18', '645000000', '정릉힐스테이트'],
#  ['성북구', '정릉동', '아파트', '2004', '59.940000', '10', '547000000', '정릉힐스테이트'],
#  ['성북구', '종암동', '아파트', '1999', '84.720000', '12', '648000000', '종암에스케이'],
#  ['성북구', '길음동', '아파트', '1988', '79.870000', '5', '380000000', '신안파크'],
#  ['성북구', '길음동', '아파트', '1988', '79.870000', '6', '379000000', '신안파크'],
#  ['성북구', '하월곡동', '아파트', '2010', '84.730000', '3', '596500000', '꿈의숲푸르지오'],
#  ['성북구', '길음동', '아파트', '2000', '59.980000', '10', '499000000', '길음현대'],
#  ['성북구', '종암동', '아파트', '2009', '84.980000', '20', '870000000', '래미안세레니티'],
#  ['성북구', '길음동', '아파트', '1988', '79.870000', '2', '345000000', '신안파크'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '15', '550000000', '한신'],
#  ['성북구', '길음동', '단독주택', '1980', '127.210000', '', '347000000', ''],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '114.910000',
#   '16',
#   '810000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '동소문동4가', '아파트', '1998', '111.550000', '14', '670000000', '송산아파트'],
#  ['성북구', '삼선동2가', '아파트', '2009', '56.830000', '9', '570000000', '삼선현대힐스테이트'],
#  ['성북구', '장위동', '연립주택', '1992', '45.300000', '4', '232000000', '태형빌라(76-234)'],
#  ['성북구', '정릉동', '연립주택', '1984', '88.380000', '3', '410000000', '대광빌라'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2007',
#   '113.230000',
#   '15',
#   '1200000000',
#   '길음뉴타운6단지(래미안)'],
#  ['성북구', '석관동', '아파트', '1998', '84.900000', '9', '630000000', '두산'],
#  ['성북구', '삼선동2가', '아파트', '2008', '84.830000', '11', '720000000', '삼선푸르지오'],
#  ['성북구', '정릉동', '아파트', '2005', '59.880000', '12', '369000000', '정릉풍림아이원'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '5', '560000000', '두산'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '2', '510000000', '두산'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '12', '550000000', '두산'],
#  ['성북구', '정릉동', '아파트', '2005', '60.000000', '13', '405000000', '정릉풍림아이원'],
#  ['성북구', '하월곡동', '아파트', '2003', '84.770000', '14', '653000000', '월곡두산위브'],
#  ['성북구', '돈암동', '아파트', '1972', '52.430000', '3', '354000000', '고명'],
#  ['성북구', '석관동', '아파트', '1998', '59.970000', '7', '590000000', '두산'],
#  ['성북구', '정릉동', '아파트', '2006', '114.560000', '17', '689000000', '정릉e-편한세상'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2006',
#   '84.960000',
#   '19',
#   '850000000',
#   '길음뉴타운5단지(래미안)'],
#  ['성북구', '장위동', '연립주택', '2003', '72.020000', '3', '250000000', '소망아트빌'],
#  ['성북구', '정릉동', '아파트', '2005', '43.920000', '10', '348000000', '정릉하이츠빌2단지'],
#  ['성북구', '석관동', '아파트', '1998', '54.550000', '22', '500000000', '두산'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '60.000000',
#   '7',
#   '610000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '상월곡동', '아파트', '2003', '126.820000', '3', '438000000', '한솔'],
#  ['성북구', '길음동', '아파트', '2010', '59.990000', '7', '830000000', '길음뉴타운8단지(래미안)'],
#  ['성북구', '장위동', '연립주택', '1996', '50.550000', '4', '140000000', '도원맨션(나)동'],
#  ['성북구', '돈암동', '단독주택', '1964', '232.860000', '', '750000000', ''],
#  ['성북구', '동선동4가', '연립주택', '1995', '45.750000', '2', '360000000', '(324-5)'],
#  ['성북구', '종암동', '아파트', '2009', '59.970000', '6', '693000000', '래미안세레니티'],
#  ['성북구', '성북동', '단독주택', '1980', '56.190000', '', '660000000', ''],
#  ['성북구', '종암동', '연립주택', '2017', '53.010000', '9', '365000000', '라움하우스'],
#  ['성북구', '정릉동', '연립주택', '2019', '57.210000', '2', '304000000', '(164-1)'],
#  ['성북구', '삼선동4가', '아파트', '1999', '59.940000', '14', '557000000', '코오롱'],
#  ['성북구', '장위동', '연립주택', '2019', '29.610000', '3', '280000000', '성준팰리스(장위초2)A'],
#  ['성북구', '하월곡동', '아파트', '2006', '84.590000', '17', '785000000', '래미안월곡'],
#  ['성북구', '정릉동', '아파트', '1999', '84.440000', '10', '597000000', '태영'],
#  ['성북구', '돈암동', '아파트', '1998', '59.580000', '2', '405000000', '한진(609-1)'],
#  ['성북구', '길음동', '아파트', '2019', '84.930000', '18', '750000000', '롯데캐슬골든힐스'],
#  ['성북구', '안암동1가', '아파트', '2005', '84.870000', '7', '605000000', '안암동삼성래미안'],
#  ['성북구', '장위동', '연립주택', '1994', '58.560000', '3', '255000000', '엘림빌라'],
#  ['성북구', '장위동', '아파트', '2008', '59.990000', '8', '620000000', '꿈의숲대명루첸아파트'],
#  ['성북구',
#   '정릉동',
#   '연립주택',
#   '1992',
#   '66.500000',
#   '-1',
#   '107000000',
#   '보광빌라(903-13)'],
#  ['성북구', '돈암동', '아파트', '2004', '59.990000', '8', '570000000', '이수브라운스톤돈암'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2003',
#   '84.840000',
#   '12',
#   '680000000',
#   '길음동동부센트레빌(1278-0)'],
#  ['성북구', '삼선동2가', '아파트', '2008', '84.840000', '1', '640000000', '삼선푸르지오'],
#  ['성북구', '장위동', '연립주택', '2019', '29.910000', '2', '245000000', '(68-957)'],
#  ['성북구', '돈암동', '연립주택', '1991', '50.600000', '-1', '300000000', '(48-36)'],
#  ['성북구', '보문동5가', '연립주택', '2019', '50.750000', '5', '497000000', '로하스빌13차'],
#  ['성북구', '정릉동', '아파트', '2001', '43.110000', '11', '288000000', '대우'],
#  ['성북구', '돈암동', '아파트', '1998', '68.130000', '3', '469000000', '한신'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '15', '590000000', '한진(609-1)'],
#  ['성북구', '정릉동', '연립주택', '1991', '50.420000', '4', '140000000', '홍우빌리지나동'],
#  ['성북구',
#   '길음동',
#   '아파트',
#   '2005',
#   '114.730000',
#   '18',
#   '810000000',
#   '길음뉴타운2단지푸르지오'],
#  ['성북구', '성북동', '단독주택', '1985', '25.140000', '', '140000000', ''],
#  ['성북구', '보문동6가', '아파트', '2017', '45.810000', '11', '640000000', '보문파크뷰자이'],
#  ['성북구', '종암동', '아파트', '1998', '59.170000', '8', '360000000', '선경(127)'],
#  ['성북구', '장위동', '연립주택', '1995', '37.690000', '1', '130000000', '창신빌라7차'],
#  ['성북구', '돈암동', '아파트', '1998', '84.870000', '18', '650000000', '한진(609-1)'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '12', '450000000', '동아에코빌'],
#  ['성북구', '정릉동', '아파트', '2008', '84.970000', '7', '630000000', '정릉힐스테이트3차'],
#  ['성북구', '동소문동6가', '오피스텔', '2015', '18.440000', '5', '199000000', '시티플레이스'],
#  ['성북구', '상월곡동', '아파트', '2003', '84.970000', '11', '585000000', '동아에코빌'],
#  ['성북구', '상월곡동', '아파트', '2003', '59.950000', '16', '468000000', '동아에코빌'],
#  ['성북구', '동선동4가', '연립주택', '1991', '59.210000', '4', '370000000', '우정빌라(나)'],
#  ['성북구', '하월곡동', '아파트', '1996', '84.690000', '15', '475000000', '아남'],
#  ['성북구', '안암동1가', '아파트', '2005', '59.700000', '7', '610000000', '안암동삼성래미안'],
#  ['성북구', '정릉동', '연립주택', '2018', '31.410000', '5', '227000000', '삼성그린빌라'],
#  ['성북구', '길음동', '단독주택', '1997', '149.570000', '', '410000000', ''],
#  ['성북구', '길음동', '단독주택', '1940', '25.090000', '', '230000000', ''],
#  ['성북구', '길음동', '단독주택', '1985', '51.300000', '', '420000000', ''],
#  ['성북구', '길음동', '단독주택', '1983', '39.670000', '', '270000000', ''],
#  ['성북구', '길음동', '단독주택', '1958', '69.420000', '', '540000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '26.450000', '', '470000000', ''],
#  ['성북구', '길음동', '단독주택', '1940', '33.060000', '', '270000000', ''],
#  ['성북구', '길음동', '단독주택', '1967', '131.770000', '', '600000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '66.120000', '', '500000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '82.650000', '', '1030000000', ''],
#  ['성북구', '길음동', '단독주택', '1979', '70.410000', '', '2033000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '49.590000', '', '923000000', ''],
#  ['성북구', '길음동', '단독주택', '1983', '224.800000', '', '810000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '19.830000', '', '370000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '59.500000', '', '410000000', ''],
#  ['성북구', '길음동', '연립주택', '1989', '72.730000', '1', '330000000', '(1084)'],
#  ['성북구', '길음동', '단독주택', '1961', '20.960000', '', '174000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '82.650000', '', '550000000', ''],
#  ['성북구', '길음동', '단독주택', '1985', '54.780000', '', '483000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '136.800000', '', '680000000', ''],
#  ['성북구', '길음동', '연립주택', '1989', '39.870000', '-1', '138100000', '(1084)'],
#  ['성북구', '길음동', '단독주택', '1995', '69.950000', '', '710000000', ''],
#  ['성북구', '길음동', '연립주택', '1991', '64.260000', '2', '310000000', '(1064-25)'],
#  ['성북구', '길음동', '단독주택', '1985', '69.950000', '', '516000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '52.890000', '', '400000000', ''],
#  ['성북구', '길음동', '단독주택', '1973', '125.590000', '', '530000000', ''],
#  ['성북구', '길음동', '단독주택', '1973', '318.120000', '', '990000000', ''],
#  ['성북구', '길음동', '연립주택', '1991', '64.260000', '1', '330000000', '(1064-25)'],
#  ['성북구', '길음동', '단독주택', '1940', '29.750000', '', '270000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '39.670000', '', '300000000', ''],
#  ['성북구', '길음동', '단독주택', '1985', '42.390000', '', '470000000', ''],
#  ['성북구', '길음동', '단독주택', '1984', '31.000000', '', '260000000', ''],
#  ['성북구', '길음동', '단독주택', '1991', '197.990000', '', '930000000', ''],
#  ['성북구', '길음동', '단독주택', '1963', '59.870000', '', '930000000', ''],
#  ['성북구', '길음동', '단독주택', '1961', '51.800000', '', '1000000000', ''],
#  ['성북구', '길음동', '단독주택', '1961', '22.740000', '', '180000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '29.750000', '', '180000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '32.140000', '', '150000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '23.140000', '', '110000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '59.500000', '', '340000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '42.980000', '', '250000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '39.670000', '', '310000000', ''],
#  ['성북구', '길음동', '단독주택', '1981', '56.660000', '', '340000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '49.590000', '', '299000000', ''],
#  ['성북구', '길음동', '연립주택', '1992', '43.500000', '1', '200000000', '(524-60)'],
#  ['성북구', '길음동', '연립주택', '1995', '43.390000', '2', '180000000', '(524-53)'],
#  ['성북구', '길음동', '연립주택', '1995', '40.550000', '-1', '130000000', '(524-53)'],
#  ['성북구', '길음동', '단독주택', '1961', '34.550000', '', '290000000', ''],
#  ['성북구', '길음동', '아파트', '1975', '81.220000', '4', '300000000', '신아'],
#  ['성북구', '길음동', '단독주택', '1965', '72.200000', '', '590000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '26.450000', '', '280000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '79.340000', '', '450000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '26.450000', '', '165000000', ''],
#  ['성북구', '길음동', '단독주택', '1958', '36.360000', '', '750000000', ''],
#  ['성북구', '길음동', '단독주택', '1985', '40.020000', '', '340000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '33.060000', '', '136000000', ''],
#  ['성북구', '길음동', '단독주택', '1965', '48.200000', '', '520000000', ''],
#  ['성북구', '길음동', '단독주택', '1961', '23.970000', '', '290000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '94.580000', '', '450000000', ''],
#  ['성북구', '길음동', '단독주택', '1965', '34.650000', '', '650000000', ''],
#  ['성북구', '길음동', '단독주택', '1961', '51.200000', '', '470000000', ''],
#  ['성북구', '길음동', '연립주택', '1995', '40.550000', '1', '170000000', '(524-53)'],
#  ['성북구', '길음동', '단독주택', '1977', '145.320000', '', '550000000', ''],
#  ['성북구', '길음동', '단독주택', '1985', '107.300000', '', '640000000', ''],
#  ['성북구', '길음동', '단독주택', '1960', '51.170000', '', '490000000', ''],
#  ['성북구', '길음동', '단독주택', '1994', '145.080000', '', '420000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '50.080000', '', '410000000', ''],
#  ['성북구', '길음동', '단독주택', '1963', '62.410000', '', '720000000', ''],
#  ['성북구', '길음동', '아파트', '1975', '78.510000', '1', '390000000', '신아'],
#  ['성북구', '길음동', '단독주택', '1991', '334.600000', '', '930000000', ''],
#  ['성북구', '길음동', '단독주택', '1964', '102.380000', '', '1100000000', ''],
#  ['성북구', '길음동', '단독주택', '1980', '84.120000', '', '670000000', ''],
#  ['성북구', '길음동', '단독주택', '1940', '33.060000', '', '240000000', ''],
#  ['성북구', '길음동', '연립주택', '1992', '43.500000', '-1', '150000000', '(524-60)'],
#  ['성북구', '길음동', '단독주택', '1991', '199.650000', '', '880000000', ''],
#  ['성북구', '길음동', '단독주택', '1955', '33.060000', '', '160000000', ''],
#  ['성북구', '길음동', '단독주택', '1966', '34.710000', '', '299000000', ''],
#  ...]

# %% [markdown]
# * 2. 동 단위
#     * 해당 구에 속한 동 리스트 조회
#     * 해당 리스트를 이용해 동별 '아파트' 평균(합계/수량 or mean) 계산
#     * 동별 평균 출력

# %%
d_name = []
for lst in data_lst:
    if lst[1] in d_name:
        continue
    else:
        d_name.append(lst[1])
print(d_name)
# Out:
# ['장위동', '길음동', '석관동', '성북동', '돈암동', '정릉동', '상월곡동', '동선동5가', '동선동3가', '종암동', '삼선동1가', '하월곡동', '동소문동5가', '보문동6가', '삼선동3가', '안암동3가', '삼선동2가', '동선동1가', '삼선동4가', '안암동1가', '보문동3가', '삼선동5가', '동선동4가', '동소문동7가', '보문동1가', '동소문동4가', '보문동5가', '동소문동6가', '안암동4가', '성북동1가', '안암동5가', '보문동4가', '안암동2가', '보문동2가', '보문동7가', '동소문동1가', '동소문동2가', '동선동2가']

# %%
avg_lst = []
for dong in d_name:
    cnt = 0
    tot = 0
    for lst in data_lst:
        if lst[1] == dong and lst[2] == '아파트':
            tot += int(lst[-2])
            cnt += 1
    if cnt==0:
        avg_lst.append({"동이름":dong, "평균판매가":0, "거래건수":0})
    else:
        avg = tot/cnt
        avg_lst.append({"동이름":dong, "평균판매가":int(avg), "거래건수":cnt})
    
avg_lst
# Out:
# [{'동이름': '장위동', '평균판매가': 743787678, '거래건수': 168},
#  {'동이름': '길음동', '평균판매가': 843763421, '거래건수': 871},
#  {'동이름': '석관동', '평균판매가': 673315019, '거래건수': 253},
#  {'동이름': '성북동', '평균판매가': 332900000, '거래건수': 10},
#  {'동이름': '돈암동', '평균판매가': 675744147, '거래건수': 786},
#  {'동이름': '정릉동', '평균판매가': 529745429, '거래건수': 1072},
#  {'동이름': '상월곡동', '평균판매가': 555521739, '거래건수': 115},
#  {'동이름': '동선동5가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동선동3가', '평균판매가': 440000000, '거래건수': 1},
#  {'동이름': '종암동', '평균판매가': 739472074, '거래건수': 376},
#  {'동이름': '삼선동1가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '하월곡동', '평균판매가': 692055138, '거래건수': 506},
#  {'동이름': '동소문동5가', '평균판매가': 594531250, '거래건수': 16},
#  {'동이름': '보문동6가', '평균판매가': 824054054, '거래건수': 148},
#  {'동이름': '삼선동3가', '평균판매가': 955962962, '거래건수': 27},
#  {'동이름': '안암동3가', '평균판매가': 396111111, '거래건수': 27},
#  {'동이름': '삼선동2가', '평균판매가': 744601063, '거래건수': 94},
#  {'동이름': '동선동1가', '평균판매가': 638666666, '거래건수': 6},
#  {'동이름': '삼선동4가', '평균판매가': 671347826, '거래건수': 23},
#  {'동이름': '안암동1가', '평균판매가': 745318181, '거래건수': 33},
#  {'동이름': '보문동3가', '평균판매가': 809523255, '거래건수': 43},
#  {'동이름': '삼선동5가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동선동4가', '평균판매가': 559000000, '거래건수': 2},
#  {'동이름': '동소문동7가', '평균판매가': 709000000, '거래건수': 49},
#  {'동이름': '보문동1가', '평균판매가': 785050000, '거래건수': 4},
#  {'동이름': '동소문동4가', '평균판매가': 558630952, '거래건수': 42},
#  {'동이름': '보문동5가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동소문동6가', '평균판매가': 318600000, '거래건수': 5},
#  {'동이름': '안암동4가', '평균판매가': 211600000, '거래건수': 5},
#  {'동이름': '성북동1가', '평균판매가': 706250000, '거래건수': 2},
#  {'동이름': '안암동5가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '보문동4가', '평균판매가': 772200000, '거래건수': 10},
#  {'동이름': '안암동2가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '보문동2가', '평균판매가': 495000000, '거래건수': 2},
#  {'동이름': '보문동7가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동소문동1가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동소문동2가', '평균판매가': 0, '거래건수': 0},
#  {'동이름': '동선동2가', '평균판매가': 0, '거래건수': 0}]

# %%
import pandas as pd
df = pd.DataFrame(avg_lst)
df
# Out:
#        동이름      평균판매가  거래건수
# 0      장위동  743787678   168
# 1      길음동  843763421   871
# 2      석관동  673315019   253
# 3      성북동  332900000    10
# 4      돈암동  675744147   786
# 5      정릉동  529745429  1072
# 6     상월곡동  555521739   115
# 7    동선동5가          0     0
# 8    동선동3가  440000000     1
# 9      종암동  739472074   376
# 10   삼선동1가          0     0
# 11    하월곡동  692055138   506
# 12  동소문동5가  594531250    16
# 13   보문동6가  824054054   148
# 14   삼선동3가  955962962    27
# 15   안암동3가  396111111    27
# 16   삼선동2가  744601063    94
# 17   동선동1가  638666666     6
# 18   삼선동4가  671347826    23
# 19   안암동1가  745318181    33
# 20   보문동3가  809523255    43
# 21   삼선동5가          0     0
# 22   동선동4가  559000000     2
# 23  동소문동7가  709000000    49
# 24   보문동1가  785050000     4
# 25  동소문동4가  558630952    42
# 26   보문동5가          0     0
# 27  동소문동6가  318600000     5
# 28   안암동4가  211600000     5
# 29   성북동1가  706250000     2
# 30   안암동5가          0     0
# 31   보문동4가  772200000    10
# 32   안암동2가          0     0
# 33   보문동2가  495000000     2
# 34   보문동7가          0     0
# 35  동소문동1가          0     0
# 36  동소문동2가          0     0
# 37   동선동2가          0     0

# %%
df1= df[df['평균판매가'] != 0]
df1 = df1.sort_values(by=['거래건수'], ascending=False)

# %%
df1
# Out:
#        동이름      평균판매가  거래건수
# 5      정릉동  529745429  1072
# 1      길음동  843763421   871
# 4      돈암동  675744147   786
# 11    하월곡동  692055138   506
# 9      종암동  739472074   376
# 2      석관동  673315019   253
# 0      장위동  743787678   168
# 13   보문동6가  824054054   148
# 6     상월곡동  555521739   115
# 16   삼선동2가  744601063    94
# 23  동소문동7가  709000000    49
# 20   보문동3가  809523255    43
# 25  동소문동4가  558630952    42
# 19   안암동1가  745318181    33
# 14   삼선동3가  955962962    27
# 15   안암동3가  396111111    27
# 18   삼선동4가  671347826    23
# 12  동소문동5가  594531250    16
# 3      성북동  332900000    10
# 31   보문동4가  772200000    10
# 17   동선동1가  638666666     6
# 27  동소문동6가  318600000     5
# 28   안암동4가  211600000     5
# 24   보문동1가  785050000     4
# 29   성북동1가  706250000     2
# 22   동선동4가  559000000     2
# 33   보문동2가  495000000     2
# 8    동선동3가  440000000     1

# %% [markdown]
# * 3. 동별 평균 값을 이용해 막대 그래프
#     * 막대 그래프
#     * box plot 그래프

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

df1['평균판매가'].plot()
plt.show()

# %%
df1 = df1.sort
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-217-1f1c345b96cf> in <module>
# ----> 1 df1 = df1.sort
#       2 plt.show()
#
# ~\miniconda3\envs\multi\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
font_name=fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family=font_name)

plt.plot(df1['동이름'], df1['거래건수'])
plt.plot(df1['동이름'], df1['평균판매가'])
plt.show()
